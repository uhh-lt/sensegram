# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
from nltk.tokenize import word_tokenize
word_tokenize("This is a nice A.C.A.B text!")


word_tokenize("Этот текст содержит-текст на русском языке.")
# Out:
# ['Этот', 'текст', 'содержит-текст', 'на', 'русском', 'языке', '.']

# %%
from induction import *

# %%
inventory_fpath = "../model/wsi/cc.ru.300.vec.gz.top50.wsi-inventory.tsv"
# Out:
# defaultdict(<function __main__.<lambda>>,
#             {'акция': [Sense(keyword='скидка', cluster=['.Акция', 'скидка', 'Промоакция', 'Промо-акция', 'акцииАкция']),
#               Sense(keyword='спецоперация', cluster=['голодовка', 'спецоперация', 'провокация']),
#               Sense(keyword='акция.', cluster=['акция.'])],
#              'баба': [Sense(keyword='яга', cluster=['Баба-', 'яга', 'Параска', 'Яга']),
#               Sense(keyword='телка', cluster=['тёлка', 'баба.', 'телка']),
#               Sense(keyword='тётя', cluster=['тётя', 'тетка', 'Тетка']),
#               Sense(keyword='провокаторша', cluster=['провокаторша'])],
#              'байка': [Sense(keyword='мотоцикла', cluster=['мотоцикла', 'драндулета', 'автомобильчика', 'пепелаца', 'чоппера', 'шоссера', 'мопеда', 'мотика', 'веломобиля', 'двухподвеса', 'харлея', 'трайка', 'найнера', 'квадроцикла', 'байк', 'экипа', 'тапка', 'ездока', 'скутера']),
#               Sense(keyword='легенда', cluster=['шутка', 'легенда', 'присказка']),
#               Sense(keyword='байковая', cluster=['байковая'])],
#              'балка': [Sense(keyword='фундаментная', cluster=['арматура', 'фундаментная', 'Двутавровая', 'надрессорная']),
#               Sense(keyword='6-15Балка', cluster=['6-15Балка', '25Б1']),
#               Sense(keyword='рейка', cluster=['поперечина', 'рейка']),
#               Sense(keyword='балкой', cluster=['балкой']),
#               Sense(keyword='продольная', cluster=['продольная']),
#               Sense(keyword='стена', cluster=['стена']),
#               Sense(keyword='Змиёвская', cluster=['Змиёвская']),
#               Sense(keyword='Ялмата', cluster=['Ялмата'])],
#              'банка': [Sense(keyword='Сберегательного', cluster=['Альфа-банка', 'Инвестторгбанка', 'СМП-банка', 'Кредитпромбанка', 'Далькомбанка', 'Акибанка', 'Росэнергобанка', 'Сберегательного', 'Балтинвестбанка', 'Локо-банка', 'Локо-Банка']),
#               Sense(keyword='банка-', cluster=['банка.', 'банка.В', 'банка-']),
#               Sense(keyword='банк', cluster=['банком', 'банк'])],
#              'белка': [Sense(keyword='триптофана', cluster=['кобаламина', 'триптофана', 'глобина']),
#               Sense(keyword='белка.', cluster=['белка.', 'жира']),
#               Sense(keyword='белках', cluster=['белках'])],
#              'бит': [Sense(keyword='бит.', cluster=['256К', '32-битный', '8-бит', '16-битный', '24-разрядный', 'бит.', 'бит-', '10-бит', '12-битный', '16-бит', '10-битный', '16-разрядный', '4-битный', '12-бит', 'битный', 'битовый', '24-битный', 'пиксел']),
#               Sense(keyword='бита', cluster=['битов', 'битодержатель', 'биты', 'бита', 'битом', 'Биты'])],
#              'бор': [Sense(keyword='утес', cluster=['угор', 'утес', 'плес', 'борок']),
#               Sense(keyword='бора', cluster=['бором', 'бора', 'борами']),
#               Sense(keyword='молибден', cluster=['кремний', 'неметалл', 'молибден']),
#               Sense(keyword='сыр-', cluster=['сыр-', 'сыр']),
#               Sense(keyword='луг', cluster=['луг', 'ручей']),
#               Sense(keyword='посад', cluster=['посад']),
#               Sense(keyword='Сосновый', cluster=['Сосновый']),
#               Sense(keyword='мен', cluster=['мен']),
#               Sense(keyword='раменье', cluster=['раменье']),
#               Sense(keyword='боре', cluster=['боре']),
#               Sense(keyword='шишкин', cluster=['шишкин']),
#               Sense(keyword='Шушенский', cluster=['Шушенский']),
#               Sense(keyword='торий', cluster=['торий']),
#               Sense(keyword='борат', cluster=['борат']),
#               Sense(keyword='ковый', cluster=['ковый']),
#               Sense(keyword='бору', cluster=['бору'])],
#              'бум': [Sense(keyword='скачок', cluster=['Коллапс', 'переполох', 'переворот', 'сдвиг', 'прорыв', 'взрыв', 'скачок']),
#               Sense(keyword='разгул', cluster=['психоз', 'повальный', 'бэби-бум', 'разгул']),
#               Sense(keyword='бума', cluster=['бума']),
#               Sense(keyword='движняк', cluster=['движняк'])],
#              'бычок': [Sense(keyword='окурок', cluster=['керчак', 'толстолоб', 'бычек', 'лещ', 'бычки', 'судак', 'карп', 'сомик', 'окурок']),
#               Sense(keyword='телёнок', cluster=['барашек', 'козлик', 'телёнок', 'козленок', 'поросёнок']),
#               Sense(keyword='жук', cluster=['горбатый', 'жук', 'головастик']),
#               Sense(keyword='подкаменщик', cluster=['подкаменщик', 'оленёк', 'бычок-подкаменщик']),
#               Sense(keyword='бычка', cluster=['бычка'])],
#              'вал': [Sense(keyword='ротор', cluster=['коленчатый', 'шатунный', 'карданный', 'эксцентриковый', 'шарикоподшипник', 'редуктор', 'ротор', 'подшипниковый', 'подшипник', 'шпиндель']),
#               Sense(keyword='шестерню', cluster=['валу', 'шестерню']),
#               Sense(keyword='вала', cluster=['контрпривода', 'вала']),
#               Sense(keyword='ров', cluster=['ров']),
#               Sense(keyword='шестерни', cluster=['шестерни']),
#               Sense(keyword='мост', cluster=['мост']),
#               Sense(keyword='вале', cluster=['вале']),
#               Sense(keyword='почувство', cluster=['почувство'])],
#              'вид': [Sense(keyword='внешний', cluster=['характер', 'вид-', 'вид.', 'удручающий', 'неказистый', 'приглядный', 'первоначальный', '-вид', 'непрезентабельный', 'непривлекательный', 'видок', 'вид.-', 'страшноватый', 'пристойный', 'устрашающий', 'видон', 'облик', 'дизайн', 'стиль', 'привлекательный', 'Внешний', 'малопривлекательный', 'неприглядный', 'внешний']),
#               Sense(keyword='эффектный', cluster=['эффектный', 'красивый', 'необыкновенный', 'потрясающий', 'восхитительный', 'необычный', 'особый']),
#               Sense(keyword='специфический', cluster=['специфический', 'подвид', 'признак', 'самостоятельный']),
#               Sense(keyword='виды', cluster=['вида', 'видов', 'виды']),
#               Sense(keyword='видом', cluster=['видом', '.Вид']),
#               Sense(keyword='способ', cluster=['способ'])],
#              'винт': [Sense(keyword='штуцер', cluster=['колпачок', 'барашковый', 'жиклер', 'шарикоподшипник', 'стопорный', 'колпачёк', 'штуцер', 'фланец', 'регулировочный', 'маховичок', 'поджимной']),
#               Sense(keyword='саморез', cluster=['вкрученный', 'самонарезающий', 'болтик', 'шуруп', 'болт.', 'тросс', 'шестигранник', 'о-ринг', 'саморез']),
#               Sense(keyword='винты', cluster=['винтом', 'винте', 'винта', 'винты']),
#               Sense(keyword='диск', cluster=['диск', 'винчестер']),
#               Sense(keyword='флайбар', cluster=['флайбар', 'импеллер']),
#               Sense(keyword='переходник', cluster=['адаптер', 'переходник']),
#               Sense(keyword='двухлопастной', cluster=['двухлопастной'])],
#              'газ': [Sense(keyword='газ.', cluster=['бензинчик', 'балонный', 'газ-носитель', 'сланцевый', 'пропан', 'светильный', 'водород', 'газоконденсат', 'газифицированный', 'газовый', 'автогаз', 'газ.В', 'газ.', 'газ-', 'баллонный', 'пропан-бутан', 'метан']),
#               Sense(keyword='энергоресурсы', cluster=['уголь', 'электроэнергию', 'электричество', 'энергоносители', 'мазут', 'энергоресурс', 'энергоноситель', 'энергоносителем', 'энергоресурсы', 'топливо']),
#               Sense(keyword='газу', cluster=['газу', 'газа-', 'газа', 'газом']),
#               Sense(keyword='газопровод', cluster=['газопровод'])],
#              'гвоздика': [Sense(keyword='роза', cluster=['анис', 'мята', 'корица', 'малина', 'паприка', 'роза']),
#               Sense(keyword='гвоздик', cluster=['гвоздиках', 'гвоздичек', 'гвоздик']),
#               Sense(keyword='булавочка', cluster=['булавочка'])],
#              'гипербола': [Sense(keyword='метонимия', cluster=['звукопись', 'метонимия', 'выдумка', 'метафора']),
#               Sense(keyword='парабола', cluster=['парабола', 'асимптота']),
#               Sense(keyword='тригонометрическая', cluster=['тригонометрическая', 'Гиперболическая']),
#               Sense(keyword='гиперболический', cluster=['гиперболический']),
#               Sense(keyword='преувеличение', cluster=['преувеличение'])],
#              'горе': [Sense(keyword='скале', cluster=['скале', 'Байгоре', 'Погоре', 'горушке', 'склоне', 'сопке', 'горой', 'горке', 'погоре', 'косогоре', 'угоре']),
#               Sense(keyword='горе.', cluster=['Студеной', 'Валутиной', 'Секирной', 'Чернечей', 'Галичьей', 'Горбатой', 'поклонной', 'Лысой', 'горе.', 'Поклонной', 'Туговой']),
#               Sense(keyword='несчастье', cluster=['бедствие', 'огорчение', 'злосчастье', 'несчастье', 'постигшее', 'печали', 'скорбь', 'счастье', 'страдание', 'страдания']),
#               Sense(keyword='ущелье', cluster=['ущелье', 'долине', 'горах', 'пещере']),
#               Sense(keyword='Гризим', cluster=['Гризим', 'Гаризим']),
#               Sense(keyword='Федорино', cluster=['Федорино', 'Егорино']),
#               Sense(keyword='луковое', cluster=['луковое'])],
#              'горн': [Sense(keyword='факельный', cluster=['факельный', 'пастуший', 'плотничий', 'паровоздушный', 'тифон', 'паровозный', 'кузнечный']),
#               Sense(keyword='рудник', cluster=['горняцкий', 'рудник', 'шахтерский', 'рудничный', 'штрек', 'рудокоп']),
#               Sense(keyword='тамбурин', cluster=['глокеншпиль', 'тамбурин', 'барабан', 'варган', 'гонг', 'бубен']),
#               Sense(keyword='горны', cluster=['горны', 'горнов', 'горна']),
#               Sense(keyword='тигельный', cluster=['тигель', 'тигельный', 'блюминг']),
#               Sense(keyword='колошник', cluster=['колосник', 'колошник', 'дымарь']),
#               Sense(keyword='мундштучный', cluster=['мундштучный', 'кавал', 'бурильный']),
#               Sense(keyword='топор', cluster=['молот', 'топор', 'молоток']),
#               Sense(keyword='кремневый', cluster=['кремневый', 'глиняный']),
#               Sense(keyword='горне', cluster=['горне']),
#               Sense(keyword='громовый', cluster=['громовый']),
#               Sense(keyword='Пастуший', cluster=['Пастуший']),
#               Sense(keyword='каминный', cluster=['каминный']),
#               Sense(keyword='горнист', cluster=['горнист'])],
#              'град': [Sense(keyword='градъ', cluster=['Киев-град', 'преславный', 'градъ', 'Первопрестольный', 'первопрестольный', 'стольный', 'ангольскийбоснийский', 'пресветлый', 'Стольный', 'царствующий', 'древян', 'Чуден', 'Красуйся', 'святый']),
#               Sense(keyword='град.', cluster=['360град', '30град', 'грд', '20º', 'градусов', '90град', 'град.', 'градусный', '45град']),
#               Sense(keyword='шквал', cluster=['ливень', 'ветрище', 'град15', 'дождь', 'шквал']),
#               Sense(keyword='града', cluster=['градин', 'градом', 'града', 'градины']),
#               Sense(keyword='градов', cluster=['граде', 'градов', 'грады', 'градах']),
#               Sense(keyword='градС', cluster=['градС', 'град.C', 'град.С.']),
#               Sense(keyword='Оравский', cluster=['Оравский']),
#               Sense(keyword='Китеж', cluster=['Китеж']),
#               Sense(keyword='камен', cluster=['камен']),
#               Sense(keyword='хлад', cluster=['хлад'])],
#              'граф': [Sense(keyword='герцог', cluster=['король', 'лорд', 'Эверард', 'эрл', 'Герцог', 'барон', 'маркиз', 'виконт', 'Бекингем', 'аристократ', 'сквайр', 'герцог', 'вельможа', 'дворянин', 'Деймиен', 'Рэтленд', 'князь', 'кузен', 'Келюс', 'Галеран', 'аббат']),
#               Sense(keyword='графа', cluster=['графа', 'графах', 'графини', 'Графы', 'графы', 'графами', 'графам']),
#               Sense(keyword='штаб-ротмистр', cluster=['фельдмаршал', 'гофмаршал', 'генерал', 'флигель-адъютант', 'полковник', 'штаб-ротмистр']),
#               Sense(keyword='Орлов-Денисов', cluster=['Орлов-Денисов', 'Орлов-Давыдов', 'Нулин']),
#               Sense(keyword='орграф', cluster=['подграф', 'орграф']),
#               Sense(keyword='Морсер', cluster=['Морсер']),
#               Sense(keyword='Донамор', cluster=['Донамор'])],
#              'губа': [Sense(keyword='Порья', cluster=['Нерпичья', 'Белушья', 'Порья', 'Колвица', 'Буор-Хая']),
#               Sense(keyword='щека', cluster=['шея', 'щека', 'щечка', 'задница']),
#               Sense(keyword='Чаунская', cluster=['Тазовская', 'Чаунская', 'Байдарацкая']),
#               Sense(keyword='губой', cluster=['губой']),
#               Sense(keyword='Перепонка', cluster=['Перепонка'])],
#              'гусеница': [Sense(keyword='червяк', cluster=['паук', 'лягушка', 'кузнечик', 'бабочка', 'жук', 'червяк']),
#               Sense(keyword='гусеницей', cluster=['гусеницей', 'гусеницами', 'гусеницам']),
#               Sense(keyword='тля', cluster=['тля', 'пяденица', 'жужелица']),
#               Sense(keyword='гусеничная', cluster=['гусеничная']),
#               Sense(keyword='Гусеничная', cluster=['Гусеничная']),
#               Sense(keyword='личиночная', cluster=['личиночная'])],
#              'давление': [Sense(keyword='давление-', cluster=['давл', '.Давление', 'давление-', 'давление10', 'давлениедо', 'разрежение', 'давление8', 'давления.', 'атм']),
#               Sense(keyword='оказываемое', cluster=['воздействие', 'влияние', 'оказываемое']),
#               Sense(keyword='давлением', cluster=['давлением'])],
#              'дама': [Sense(keyword='женщина', cluster=['мамзель', 'мадама', 'дамочка', 'женщина', 'дева']),
#               Sense(keyword='Дамочка', cluster=['Дамочка']),
#               Sense(keyword='графиня', cluster=['графиня'])],
#              'данные': [Sense(keyword='сведения', cluster=['Уточненные', 'объективные', 'достоверные', 'фактические', 'точные', 'сведения', 'биографические', 'итоговые', 'систематизированные', 'официальные', 'статистические']),
#               Sense(keyword='данные.', cluster=['авторизационные', 'данные.В', 'данные.', 'даные', 'даннные', 'паспортные']),
#               Sense(keyword='полученные', cluster=['полученные', 'вычисленные', 'обнародованные', 'суммированные', 'лученные']),
#               Sense(keyword='эти', cluster=['вышеуказанные', 'указанные', 'вышеупомянутые', 'эти'])],
#              'дар': [Sense(keyword='подаренный', cluster=['дарован', 'дарованная', 'благословенный', 'подаренный', 'преподнесенный', 'ниспосланный', 'дарованный']),
#               Sense(keyword='дар.', cluster=['драгоценный', 'незаслуженный', 'драгоценнейший', 'безценный', 'дар.', 'дар-', 'бесценный']),
#               Sense(keyword='экстрасенсорный', cluster=['необыкновенный', 'сверхъестественный', 'целительский', 'магический', 'экстрасенсорный']),
#               Sense(keyword='дара', cluster=['дара', 'предвиденья', 'ясновиденья', 'предвидения']),
#               Sense(keyword='пророческий', cluster=['пророческий', 'провидческий', 'ораторский', 'поэтический']),
#               Sense(keyword='Божий', cluster=['Б-жий', 'Божий']),
#               Sense(keyword='талант', cluster=['талант', 'навык']),
#               Sense(keyword='дары', cluster=['даров', 'дары']),
#               Sense(keyword='врожденный', cluster=['наследственный', 'врожденный']),
#               Sense(keyword='безвозмездный', cluster=['безвозмездный']),
#               Sense(keyword='благословение', cluster=['благословение']),
#               Sense(keyword='подарок', cluster=['подарок'])],
#              'дата': [Sense(keyword='-дата', cluster=['экз.Дата', '.Дата', '-дата', 'г.Дата', 'дата1', 'дата.', 'годаДата', '18.10.1989гдата', 'года.Дата', 'PCДата', '-Дата', 'СШАДата', 'гДата']),
#               Sense(keyword='дата-', cluster=['знаменательная', 'условная', 'некруглая', 'дата-', 'Знаменательная', 'датами']),
#               Sense(keyword='неизвестна.', cluster=['неизвестна.']),
#               Sense(keyword='проставлена', cluster=['проставлена']),
#               Sense(keyword='дата3', cluster=['дата3']),
#               Sense(keyword='релиза', cluster=['релиза']),
#               Sense(keyword='Ожидаемая', cluster=['Ожидаемая']),
#               Sense(keyword='Датой', cluster=['Датой'])],
#              'двигатель': [Sense(keyword='электродвигатель', cluster=['турбонагнетатель', '-двигатель', 'движитель', 'движок', 'маховик', 'турбокомпрессор', 'стартер', 'дизелек', 'дизель', 'редуктор', 'бензиновый', 'электромотор', 'карбюраторный', 'электродвигатель', 'дизелёк', 'двигателя-', 'мотор', 'турбонадув', 'двиг', 'дв-ль', 'двигун', 'дигатель']),
#               Sense(keyword='турбовальный', cluster=['авиадвигатель', 'турбовальный'])],
#              'двойка': [Sense(keyword='тройка', cluster=['Четвёрка', 'шестёрка', 'семёрка', 'семерка', 'восьмёрка', 'тройка', 'девятка', 'Восьмерка', 'Восьмёрка', 'восьмерка', 'Шестерка']),
#               Sense(keyword='трояк', cluster=['неуд', 'трояк']),
#               Sense(keyword='двойками', cluster=['двойками', 'двойкам']),
#               Sense(keyword='байдарка-двойка', cluster=['байдарка-двойка']),
#               Sense(keyword='2-ка', cluster=['2-ка']),
#               Sense(keyword='переэкзаменовка', cluster=['переэкзаменовка'])],
#              'двойник': [Sense(keyword='близнец', cluster=['биоробот', 'репликант', 'инопланетянин', 'близнец', 'мутант', 'клон', 'пришелец', 'уродец', 'перевертыш']),
#               Sense(keyword='мнимый', cluster=['фальшивый', 'мнимый', 'манекен', 'фейковый', 'фантом', 'фантомный', 'ненастоящий']),
#               Sense(keyword='двойника', cluster=['двойника', 'двойники', 'двойниках', 'Двойники', 'двойнике', 'двойником']),
#               Sense(keyword='сообщник', cluster=['брат-близнец', 'любовник', 'родственник', 'однофамилец', 'приятель', 'сообщник']),
#               Sense(keyword='призрак', cluster=['вампир', 'оборотень', 'мертвец', 'призрак']),
#               Sense(keyword='демонический', cluster=['астральный', 'бестелесный', 'демонический']),
#               Sense(keyword='трикстер', cluster=['трикстер', 'очеловеченный', 'персонаж']),
#               Sense(keyword='прихлебатель', cluster=['прихлебатель', 'антипод']),
#               Sense(keyword='портретик', cluster=['портретик']),
#               Sense(keyword='самозванец', cluster=['самозванец']),
#               Sense(keyword='зеркальный', cluster=['зеркальный']),
#               Sense(keyword='тройник', cluster=['тройник']),
#               Sense(keyword='идол', cluster=['идол'])],
#              'двор': [Sense(keyword='двор.', cluster=['балкончик', 'дворъ', 'двор-сад', 'лес.В', 'мощеный', 'двор.В', 'огороженный', 'овчий', 'балкон', 'скотный', 'подъезд', 'двор-', 'двор.']),
#               Sense(keyword='скверик', cluster=['сад', 'проулок', 'лес', 'сквер', 'пустырь', 'Дворик', 'парк', 'скверик']),
#               Sense(keyword='флигель', cluster=['дом', 'флигель', 'сарай', 'флигелек']),
#               Sense(keyword='двора', cluster=['двором', 'двора', 'дворика']),
#               Sense(keyword='дворе', cluster=['дворике', 'двори', 'дворе']),
#               Sense(keyword='улицу', cluster=['улицу']),
#               Sense(keyword='дворы', cluster=['дворы']),
#               Sense(keyword='гостинный', cluster=['гостинный'])],
#              'дворец': [Sense(keyword='дворец.', cluster=['замок-дворец', 'палац', 'стадион', 'дворец.', 'дом', 'дом-замок', 'храм', 'собор', 'парк', 'зал', 'музей', 'дворец-музей', 'дом-дворец']),
#               Sense(keyword='дворце', cluster=['Дворцу', 'дворце', 'Дворца', 'Монбижу', 'Кристиансборг', 'дворцом', 'Хофбург']),
#               Sense(keyword='покои', cluster=['покои', 'дворцов', 'Токсугун', 'Тадж-Бек', 'дворца', 'дворцы']),
#               Sense(keyword='Теремной', cluster=['Приоратский', 'Теремной']),
#               Sense(keyword='цирк', cluster=['цирк', 'театр'])],
#              'дворник': [Sense(keyword='уборщик', cluster=['истопник', 'фонарщик', 'таксист', 'мусорщик', 'шофер', 'гастарбайтер', 'тракторист', 'парковщик', 'плотник', 'сторож', 'садовник', 'управдом', 'грузчик', 'кровельщик', 'дворничиха', 'каменщик', 'повар', 'уборщик', 'стекольщик', 'вахтер', 'водитель', 'охранник', 'бездельник', 'завхоз', 'милиционер', 'слесарь', 'бульдозерист', 'экскаваторщик', 'автослесарь', 'коммунальщик', 'автомойщик', 'бомж', 'мойщик', 'интеллигент', 'уборщица', 'маляр']),
#               Sense(keyword='дворники', cluster=['стеклоочиститель', 'дворниками', 'дворника', 'дворнике', 'дворники', 'дворниках']),
#               Sense(keyword='собачник', cluster=['собачник'])],
#              'девка': [Sense(keyword='шалава', cluster=['тетка', 'шалава', 'молодуха', 'тёлочка', 'девица', 'девчонка'])],
#              'девочка': [Sense(keyword='девочка.', cluster=['красавица', 'кошка', 'девочка-девочка', 'девчоночка', 'мамочка', 'девка', 'барышня', 'бабушка', 'дочечка', 'старушка', 'девица', 'голубоглазая', '-девочка', 'девчурка', 'музыкантка', 'кошечка', 'мама', 'девченка', 'девчушка', 'малышка', 'девочка.', 'Малышка', 'девачка', 'девушка', 'девчёнка', 'светловолосая', 'красотка', 'Девочка-', 'девочка-то', 'дочка']),
#               Sense(keyword='восьмиклассница', cluster=['сверстница', 'четырнадцатилетняя', 'второклассница', 'семиклассница', 'восьмиклассница', 'третьеклассница', 'первоклассница', 'шестиклассница', 'школьница', 'пятиклассница']),
#               Sense(keyword='мальчик', cluster=['мальчик']),
#               Sense(keyword='Мальчик', cluster=['Мальчик'])],
#              'девушка': [Sense(keyword='женщина', cluster=['деваха', 'дама', 'дувушка', 'байкерша', 'девчёнка', 'азиатка', 'мулатка', 'девушка-подросток', 'девица', 'женщина']),
#               Sense(keyword='парень', cluster=['парень'])],
#              'девчонка': [Sense(keyword='девчушка', cluster=['девчушка']),
#               Sense(keyword='стерва', cluster=['стерва'])],
#              'девятка': [Sense(keyword='шестёрка', cluster=['двойка', 'Двойка', 'восьмёрка', 'Четверка', 'Десятка', 'Семёрка', 'шестёрка', 'Трефовая', 'Восьмерка', 'Семерка', 'Восьмёрка', 'восьмерка', 'Пятерка', 'Шестерка']),
#               Sense(keyword='двенашка', cluster=['9-ка', 'двенашка', 'машина', 'иномарка', 'пятнашка', 'Приора']),
#               Sense(keyword='девяток', cluster=['девятками', 'девяток', 'семерок']),
#               Sense(keyword='четырке', cluster=['четырке'])],
#              'дед': [Sense(keyword='прадед', cluster=['Дедушка', 'Прадед', 'дедушка', 'Дедуля', 'дядька', 'дядюшка', 'старик', 'прадед', 'старичок', 'дядя', 'папа', 'внучок', 'Внук', 'дедко', '.Дед', 'дедуля', 'Прадедушка', 'папаша', 'внучек', 'двоюродный', 'дедушко', 'дедок', 'отец'])],
#              'дедушка': [Sense(keyword='прадедушка', cluster=['прапрадедушка', 'бабушка', 'дядюшка', 'прадедушка', 'дед', 'прадед', 'дядя', 'тетя', 'папа', 'прабабушка', 'дедушкин', 'правнук', 'сын', 'кузен', 'сынок', 'Прадедушка', 'деда', 'папаша', 'мальчик', 'внучка', 'бабуля', 'отец', 'отчим']),
#               Sense(keyword='дедуля', cluster=['старик', 'дяденька', 'дедуля', 'старикан', 'старичок', 'дедулька', 'Дедуля', 'дядька', 'дедок'])],
#              'дежурная': [Sense(keyword='эвакуационная', cluster=['инженерно-саперная', 'парашютно-десантная', 'пожарная', 'Аварийно-спасательная', 'поликлиническая', 'объектовая', 'спасательная', 'эвакуационная', 'горноспасательная', 'реанимационная', 'внутриведомственная', 'опознавательная', 'аварийно-спасательная']),
#               Sense(keyword='дежурный', cluster=['дежурке', 'дежурные', 'дежурной', 'дежурный']),
#               Sense(keyword='администраторша', cluster=['вахтёрша', 'вахтерша', 'администраторша']),
#               Sense(keyword='милицейская', cluster=['ментовская', 'гаишная', 'милицейская']),
#               Sense(keyword='Бдительная', cluster=['Бдительная']),
#               Sense(keyword='пожилая', cluster=['пожилая']),
#               Sense(keyword='бездействующая', cluster=['бездействующая'])],
#              'дежурный': [Sense(keyword='фельдшер', cluster=['командир', 'вахтер', 'сторож', 'Дневальный', 'комитетчик', 'дозиметрист', 'фельдшер', 'охранник', 'комендант', 'завхоз']),
#               Sense(keyword='дежурного', cluster=['дежурного', 'дежурному']),
#               Sense(keyword='полицейский', cluster=['милицейский', 'полицейский']),
#               Sense(keyword='оперативный', cluster=['круглосуточный', 'оперативный']),
#               Sense(keyword='дозорный', cluster=['дозорный', 'бдительный']),
#               Sense(keyword='дежурная', cluster=['дежурная']),
#               Sense(keyword='старший', cluster=['старший'])],
#              'дезертир': [Sense(keyword='шпион', cluster=['танкист', 'контрабандист', 'спецназовец', 'десантник', 'диверсант', 'шпион', 'бандит', 'повстанец', 'мародер', 'наёмник', 'уголовник', 'каратель']),
#               Sense(keyword='дезертиры', cluster=['дезертирство', 'дезертиры', 'дезертировать', 'дезертирству', 'дезертирстве', 'дезертиром', 'дезертирах', 'дезертиров']),
#               Sense(keyword='военнопленный', cluster=['беженец', 'военнопленный']),
#               Sense(keyword='дезертиру', cluster=['дезертиру']),
#               Sense(keyword='Дезертиры', cluster=['Дезертиры']),
#               Sense(keyword='уклонист', cluster=['уклонист'])],
#              'действие': [Sense(keyword='вдействие', cluster=['введения', 'действие.В', 'Действо', 'вдействие', '.Действие', 'действие.']),
#               Sense(keyword='разворачивающееся', cluster=['разворачивающееся', 'действо', 'действующее']),
#               Sense(keyword='пролонгированное', cluster=['последействие', 'влияние', 'пролонгированное']),
#               Sense(keyword='отрезвляющее', cluster=['действие-', 'отрезвляющее']),
#               Sense(keyword='последствие', cluster=['последствие']),
#               Sense(keyword='применение', cluster=['применение']),
#               Sense(keyword='усиливающее', cluster=['усиливающее']),
#               Sense(keyword='действием', cluster=['действием']),
#               Sense(keyword='взаимодействие', cluster=['взаимодействие'])],
#              'действительность': [Sense(keyword='явленность', cluster=['бытийность', 'вещность', 'изобразительность', 'самоочевидность', 'явленность']),
#               Sense(keyword='реальность', cluster=['реальность', 'повседневность', 'реалии', 'обыкновенность']),
#               Sense(keyword='исполнимость', cluster=['исполнимость'])],
#              'декабрист': [Sense(keyword='якобинец', cluster=['контрреволюционер', 'славянофил', 'писатель-мемуарист', 'писатель-демократ', 'революционер-демократ', 'якобинец']),
#               Sense(keyword='декабриста', cluster=['декабристы', 'декабристов', 'декабриста']),
#               Sense(keyword='Зигокактус', cluster=['Зигокактус']),
#               Sense(keyword='зигокактус', cluster=['зигокактус'])],
#              'декларация': [Sense(keyword='3НДФЛ', cluster=['3НДФЛ', '3-НДФЛ']),
#               Sense(keyword='резолюция', cluster=['резолюция']),
#               Sense(keyword='декларацией', cluster=['декларацией']),
#               Sense(keyword='заполненияДекларация', cluster=['заполненияДекларация'])],
#              'декорация': [Sense(keyword='ширма', cluster=['композиция', 'массовка', 'бутафория', 'бутафорская', 'киношная', 'мизансцена', 'ширма', 'видеопроекция', 'сцена']),
#               Sense(keyword='декор', cluster=['декор']),
#               Sense(keyword='декорациям', cluster=['декорациям']),
#               Sense(keyword='антуража', cluster=['антуража'])],
#              'декрет': [Sense(keyword='дикрет', cluster=['Декреты', 'декретам', 'дикрет', 'декрете', 'декрета', 'Декрета', 'декреталии', 'Декретные', 'декрету', 'декреты', 'декретах', 'декретов', 'декретом', 'тунеядцах', 'Декретом', 'декретами']),
#               Sense(keyword='указ', cluster=['Указ', 'приказ', 'эдикт', 'законопроект', 'закон', 'указ', 'постановление', 'ордонанс']),
#               Sense(keyword='Декретный', cluster=['Декретный'])],
#              'делегат': [Sense(keyword='представитель', cluster=['содокладчик', 'лектор', 'координатор', 'председатель', 'спикер', 'арбитр', 'руководитель', 'стенографист', 'комиссар', 'представитель', 'президент', 'инспектор', 'отборщик', 'активист', 'коммунист', 'заседатель', 'сенатор', 'наблюдатель', 'вице-президент', 'судья', 'меньшевик', 'комитетчик', 'хронометрист', 'депутат', 'правозащитник', 'секретарь', 'докладчик', 'посол']),
#               Sense(keyword='делегата', cluster=['делегата', 'Делегаты', 'делегатов', 'делегатам', 'делегаты']),
#               Sense(keyword='священник', cluster=['священник']),
#               Sense(keyword='delegate', cluster=['delegate']),
#               Sense(keyword='комиссионер', cluster=['комиссионер'])],
#              'деление': [Sense(keyword='разделение', cluster=['делени', 'разделение', 'делением']),
#               Sense(keyword='вычитание', cluster=['вычитание', '-умножение']),
#               Sense(keyword='однозначное', cluster=['однозначное']),
#               Sense(keyword='дробное', cluster=['дробное'])],
#              'дело': [Sense(keyword='дело-то', cluster=['муторное', 'хлопотное', 'безнадежное', 'нешуточное', 'житейское', 'начатое', 'небыстрое', 'поправимое', 'несложное', 'рискованное', 'дохлое', '-Дело', 'сложное', 'дело-то', 'гиблое', 'решенное', 'нетрудное', 'серьезное', 'непростое', 'обычное', 'нелегкое', 'Дело-то', 'решаемое', 'ясное', '.Дело', 'пустяковое']),
#               Sense(keyword='дело.', cluster=['дело.На', 'дело.А', 'дело.В', 'дело.', 'дело-', 'дело.Как', 'дело.По']),
#               Sense(keyword='уголовное', cluster=['уголовное', 'разбирательство', 'заведенное']),
#               Sense(keyword='делом', cluster=['делом'])],
#              'дельфин': [Sense(keyword='слоник', cluster=['лягушонок', 'бегемотик', 'жираф', 'слоник', 'носорог', 'бегемот']),
#               Sense(keyword='дельфином', cluster=['дельфином']),
#               Sense(keyword='дельфины', cluster=['дельфины']),
#               Sense(keyword='альбатрос', cluster=['альбатрос'])],
#              'демобилизация': [Sense(keyword='демобилизованных', cluster=['демобилизованный', 'демобилизуется', 'демобилизованных', 'демобилизоваться', 'дембель', 'демобилизовалась', 'демобилизованные', 'демобилизована', 'демобилизовавшись', 'демобилизацией']),
#               Sense(keyword='мобилизация', cluster=['отставка', 'оккупация', 'демилитаризация', 'деморализация', 'капитуляция', 'мобилизация', 'передислокация'])],
#              'демократ': [Sense(keyword='республиканец', cluster=['монархист', 'сенатор-демократ', 'гуманист', 'интеллектуал', 'федералист', 'президент-демократ', 'политикан', 'политик-демократ', 'диктатор', 'республиканец', 'технократ', 'либерал', 'реформатор', 'патриот', 'демагог', 'феминист', 'политик']),
#               Sense(keyword='демократа', cluster=['демократы', 'демократов', 'демократа']),
#               Sense(keyword='либеральный', cluster=['либеральный', 'демократический']),
#               Sense(keyword='демократом', cluster=['демократом'])],
#              'демократия': [Sense(keyword='олигархия', cluster=['Дерьмократия', 'олигархия', 'дерьмократия', 'автократия']),
#               Sense(keyword='политическая', cluster=['двухпартийная', 'конституционная', 'идеология', 'политическая']),
#               Sense(keyword='Свобода', cluster=['Свобода']),
#               Sense(keyword='свобода', cluster=['свобода']),
#               Sense(keyword='демократией', cluster=['демократией'])],
#              'демонстрация': [Sense(keyword='демонстрацией', cluster=['демонстрацией']),
#               Sense(keyword='кульминация', cluster=['кульминация']),
#               Sense(keyword='монстрация', cluster=['монстрация'])],
#              'день': [Sense(keyword='вечер', cluster=['деньНа', 'деньс', 'дня', 'вечер.В', 'вдень', 'день4', 'день.И', 'деньИ', 'вечер', 'день.5', 'будний', 'деньС']),
#               Sense(keyword='месяц', cluster=['месяц', 'год']),
#               Sense(keyword='следующий', cluster=['следующий']),
#               Sense(keyword='Дня', cluster=['Дня']),
#               Sense(keyword='дни', cluster=['дни'])],
#              'деньги': [Sense(keyword='деньги.', cluster=['денежку', 'деньжата', 'деньги-', 'денюшки', 'копеечки', 'госденьги', 'деньги-то', 'денежные', 'заработанные', 'немалые', 'деньги.', 'Денежки', 'бабло', 'доллары', 'бабки', 'денежки', 'деньги-это', 'наличные', '-деньги', 'денюжку', 'денежки-то']),
#               Sense(keyword='деньгиАфоризмы', cluster=['деньгиАфоризмы'])],
#              'деревня': [Sense(keyword='Якимиха', cluster=['Пяхта', '019деревня', 'Якимиха', 'Тимониха', 'Осиновица', '015деревня', 'Леониха', 'Сафониха', 'Афониха', 'Касимовка']),
#               Sense(keyword='Фенево', cluster=['Лбово', 'Кипино', 'Фенево', 'Екимово']),
#               Sense(keyword='Черневка', cluster=['Пичевка', 'Боровщина', 'Черневка', 'Кутьма']),
#               Sense(keyword='деревушка', cluster=['деревенька', 'деревушка']),
#               Sense(keyword='Карташовка', cluster=['Карташовка'])],
#              'дерево': [Sense(keyword='чудо-дерево', cluster=['посаженное', 'растение', 'деревце', 'чудо-дерево', 'деревцо']),
#               Sense(keyword='дерево.', cluster=['деревянное', 'дерево.', 'дуб', 'тиковое']),
#               Sense(keyword='Драконово', cluster=['Драконово']),
#               Sense(keyword='Тиковое', cluster=['Тиковое']),
#               Sense(keyword='деревья', cluster=['деревья']),
#               Sense(keyword='древесина', cluster=['древесина'])],
#              'держава': [Sense(keyword='державой', cluster=['сверхдержава', 'супердержава', 'державой', 'оборонка', 'элита', 'цивилизация', 'Империя', 'геополитика']),
#               Sense(keyword='самостийная', cluster=['монархическая', 'самостийная', 'великодержавная', 'державная']),
#               Sense(keyword='державность', cluster=['державность', 'государственность']),
#               Sense(keyword='могучая', cluster=['великая', 'могучая']),
#               Sense(keyword='Русь-Украина', cluster=['Русь', 'Русь-Украина']),
#               Sense(keyword='державою', cluster=['державою']),
#               Sense(keyword='федерация', cluster=['федерация'])],
#              'дерзость': [Sense(keyword='смелость', cluster=['заносчивость', 'бестактность', 'разнузданность', 'кичливость', 'непокорность', 'наглость', 'страстность', 'смелость', 'непочтительность'])],
#              'десант': [Sense(keyword='патруль', cluster=['конвой', 'десантник', 'флот', 'берег', 'гарнизон', 'отряд', 'экипаж', 'корабль', 'дозор', 'полк', 'десантура', 'спецназ', 'разведотряд', 'патруль', 'батальон', 'взвод', 'карабль']),
#               Sense(keyword='десанты', cluster=['десантироваться', 'десантировался', 'десантировать', 'высадился', 'десанты', 'десанта', 'десантов']),
#               Sense(keyword='десантный', cluster=['десантный']),
#               Sense(keyword='вражеский', cluster=['вражеский'])],
#              'десерт': [Sense(keyword='десерта', cluster=['сорбе', 'торт-мороженое', 'шоколад', 'трайфл', 'торт', 'десерта', 'тирамису', 'сорбет', 'зефир', 'дессерт', 'торт.']),
#               Sense(keyword='гарнир', cluster=['ужин', 'гарнир', 'завтрак', 'блюдо', 'салатик']),
#               Sense(keyword='вкусный', cluster=['вкуснейший', 'вкусный']),
#               Sense(keyword='десерты', cluster=['десерты'])],
#              'десятка': [Sense(keyword='полутора', cluster=['тридцати', 'пятнадцати', 'полутора', 'двадцати']),
#               Sense(keyword='сотня', cluster=['сотня', 'дюжина'])],
#              'десяток': [Sense(keyword='пяток', cluster=['десяточек', 'парочку', 'пяток']),
#               Sense(keyword='идин', cluster=['идин']),
#               Sense(keyword='шесть-семь', cluster=['шесть-семь']),
#               Sense(keyword='десятки', cluster=['десятки'])],
#              'деталь': [Sense(keyword='детальку', cluster=['деталь.', 'детали.', 'детальку', 'деталей', 'деталировку', 'деталька', 'запчасть', 'автозапчасть']),
#               Sense(keyword='важная', cluster=['Немаловажная', 'маловажная', 'несущественная', 'важная', 'немаловажная']),
#               Sense(keyword='сборочная', cluster=['сборочная', 'комплектующую', 'изнашиваемая', 'комплектующая']),
#               Sense(keyword='частность', cluster=['частность', 'особенность', 'характерная', 'изюминка']),
#               Sense(keyword='пласть', cluster=['выточка', 'мастер-модель', 'пласть']),
#               Sense(keyword='вещь', cluster=['вещь-', 'вещицу', 'вещь']),
#               Sense(keyword='моделька', cluster=['моделька', 'модель', 'конструкция']),
#               Sense(keyword='деталью', cluster=['деталью']),
#               Sense(keyword='важную', cluster=['важную']),
#               Sense(keyword='накладка', cluster=['накладка']),
#               Sense(keyword='часть', cluster=['часть'])],
#              'детектив': [Sense(keyword='триллер', cluster=['криминал', 'роман', 'мелодрама', 'детектив.', 'триллер', 'кинороман', 'сериал', 'остросюжетный', 'мелодр', 'триллер-детектив', 'боевик']),
#               Sense(keyword='сыщик', cluster=['девушка-детектив', 'детектив-инспектор', 'спецагент', 'криминалист', 'сыщика', 'детективов', 'следователь', 'женщина-детектив', 'детектив-любитель', 'сыщик-любитель', 'сыщик']),
#               Sense(keyword='детективЯзык', cluster=['детективСерия', 'детективОписание', 'детективВ', 'детективЯзык', 'детективГод', 'детективИздательство']),
#               Sense(keyword='детективом', cluster=['детективом']),
#               Sense(keyword='детективе', cluster=['детективе'])],
#              'дети': [Sense(keyword='внуки', cluster=['дошкольники', 'Малыши', 'сыновья', 'ученики', 'младенцы', 'внуки', 'дети.', 'отцы', 'Родители', 'мальчики', 'детки', 'школьники', 'воспитатели', 'груднички', 'Детишки', 'новорожденные', 'дети.-', 'сверстники', 'дети-внуки', 'учащиеся', 'дети-то', '-дети', 'дети-аутисты', 'мальчики-подростки', 'младшеклассники', 'пенсионеры', 'подростки'])],
#              'деятель': [Sense(keyword='военачальник', cluster=['дипломат', 'мемуарист', 'философ-материалист', 'ученый-', 'философ', 'педагог', 'военачальник', 'писатель', 'популяризатор', 'финансист', 'деятельный', 'обществовед', 'философ-просветитель', 'авантюрист', 'просветитель', 'книгоиздатель', 'ятель', 'функционер', 'революционер', 'активист', 'мыслитель', 'теоретик', 'реформатор', 'идеолог', 'управленец', 'политик', 'писатель-драматург', 'деятель.', 'литератор', 'промышленник', 'историк']),
#               Sense(keyword='деятель-', cluster=['деяте', 'деятел', 'деятель-']),
#               Sense(keyword='деятелем', cluster=['деятелем']),
#               Sense(keyword='деятелей', cluster=['деятелей']),
#               Sense(keyword='деятельница', cluster=['деятельница'])],
#              'деятельность': [Sense(keyword='жизнедеятельность', cluster=['жизнь', 'деятельнось', 'деятельность.', 'бизнес-деятельность', 'противозаконную', 'лицензируемая', 'своюдеятельность', 'хозяйственную', 'дея-тельности', 'деятельност', 'деятельность1', 'мыследеятельность', 'деят-сть', 'дея', 'деятельность-', 'деятельн', 'общественно-полезная', '.Деятельность', 'деятель-ности', 'предпринимательская', 'жизнедеятельность', 'предпринимательскую', 'функционирование', 'деятельностью']),
#               Sense(keyword='работа', cluster=['работа']),
#               Sense(keyword='работу', cluster=['работу'])],
#              'диагональ': [Sense(keyword='IPS-матрицу', cluster=['дисплея', 'IPS-матрицу', 'диагоналей', 'экрана', 'ЖК-монитора', 'TFT-экрана', 'IPS-матрица', 'диагональю']),
#               Sense(keyword='длина', cluster=['длина', 'ширина']),
#               Sense(keyword='диагональную', cluster=['диагональную', 'диагональная']),
#               Sense(keyword='экрана16', cluster=['ЖК-телевизорДиагональ', 'экрана16']),
#               Sense(keyword='-VA', cluster=['-VA']),
#               Sense(keyword='жк-телевизор', cluster=['жк-телевизор'])],
#              'диалог': [Sense(keyword='разговор', cluster=['монологический', 'разговор', 'конструктивный', 'дискурс', 'диалогический', 'диспут', 'переговоры', 'разгοвор', 'взаимовыгодный', 'полилог', 'сотрудничество', 'диалог-обмен', 'диалоговый', 'диалогичность', 'Разговор', 'диалогическое', 'контакт', 'конфликт', 'беспредметный', 'разговорчик', 'диалог-', 'диалогически', 'компромисс', 'переговор', 'розговор', 'консенсус', 'диалог.', 'взаимообмен', 'расспрос', 'монолог', 'общение', 'переговорный', 'взаимный', 'взаимодействие', 'спор']),
#               Sense(keyword='диалоге', cluster=['диалога', 'диалоги', 'диалогом', 'монологом', 'диалоге', 'диалогов', 'диалогах']),
#               Sense(keyword='диалогу', cluster=['диалогу'])],
#              'диаметр': [Sense(keyword='13Диаметр', cluster=['6Диаметр', '13Диаметр', 'штДиаметр', 'диаметр22', 'механизмаДиаметр', 'м.Диаметр', 'диаметр30', 'характеристикиДиаметр', 'мм.Диаметр', '22Диаметр', '24Диаметр', 'шт.Диаметр', '4Диаметр', '.Диаметр', '18Диаметр', '8Диаметр', '5Диаметр', 'ВДиаметр', '12Диаметр', 'см3Диаметр', '38Диаметр', 'гДиаметр', 'мдиаметр', '1Диаметр', 'мДиаметр', 'высота', '98Диаметр', 'см.диаметр', '9Диаметр', '3Диаметр', '21Диаметр', '19Диаметр']),
#               Sense(keyword='поперечник', cluster=['диметр', 'диаметры', 'размер', 'радиус', 'диаметре', 'поперечник', 'диаметра', 'диам'])],
#              'диво': [Sense(keyword='чудо', cluster=['дивное', 'Экое', 'чудо', 'величавое', 'златое', 'необыкновенное', 'необычайное', 'Диковинное']),
#               Sense(keyword='пригож', cluster=['пригож', 'пригожа']),
#               Sense(keyword='удивительно', cluster=['удивительно', 'сказочно']),
#               Sense(keyword='явленье', cluster=['строенье', 'явленье']),
#               Sense(keyword='лепо', cluster=['лепо', 'вельми']),
#               Sense(keyword='ноне', cluster=['Вишь', 'ноне']),
#               Sense(keyword='глядится', cluster=['глядится']),
#               Sense(keyword='дивом', cluster=['дивом']),
#               Sense(keyword='впрямь', cluster=['впрямь']),
#               Sense(keyword='невидаль', cluster=['невидаль']),
#               Sense(keyword='загляденье', cluster=['загляденье'])],
#              'диета': [Sense(keyword='диетотерапия', cluster=['детокс-программа', 'диетаДиета', 'монодиеты', 'диетотерапия', 'макробиотика', 'терапия', 'диета.', 'диетадиета', 'питаниеДиета', 'монодиета', 'Кетогенная', 'диетическая', 'Бессолевая', 'Экспресс-диета']),
#               Sense(keyword='протасова', cluster=['протасова', 'аткинса']),
#               Sense(keyword='похудение', cluster=['похудение'])],
#              'дикарь': [Sense(keyword='прямоходящий', cluster=['прямоходящий', 'двуногий']),
#               Sense(keyword='Глупец', cluster=['Глупец']),
#               Sense(keyword='одичавший', cluster=['одичавший']),
#               Sense(keyword='чужестранец', cluster=['чужестранец']),
#               Sense(keyword='дикарка', cluster=['дикарка']),
#               Sense(keyword='остолоп', cluster=['остолоп']),
#               Sense(keyword='первобытным', cluster=['первобытным'])],
#              'диктатор': [Sense(keyword='тиран', cluster=['самодержец', 'полководец', 'император', 'заговорщик', 'фюрер', 'вождь', 'временщик', 'правитель', 'палач', 'деспот', 'властолюбивый', 'бандит', 'узурпатор', 'монарх', 'тиран', 'злодей', 'царек', 'экс-диктатор', 'террорист']),
#               Sense(keyword='революционер', cluster=['демократ', 'президент-', 'революционер', 'президент-демократ', 'политикан', 'либерал', 'президент', 'демагог']),
#               Sense(keyword='диктатором', cluster=['диктаторов', 'диктатором', 'диктатора']),
#               Sense(keyword='диктаторский', cluster=['диктаторский', 'тоталитарный']),
#               Sense(keyword='диктатору', cluster=['диктатору'])],
#              'диплом': [Sense(keyword='диплом.', cluster=['диссер', 'дипломник', 'диплом.', 'дипломчик', 'курсовик', 'дипломный', 'дипломную', 'заочник', 'курсовики', 'дисер']),
#               Sense(keyword='дипломы', cluster=['колледжаДиплом', 'дипломы', 'Аттестат', 'дипломом', '.Диплом', 'наукДиплом', 'Дипломы', 'дипломанта', 'диплома']),
#               Sense(keyword='документ', cluster=['удостоверение', 'документ', 'военник', 'гознак', 'аттестат', 'паспорт', 'сертификат']),
#               Sense(keyword='спецприз', cluster=['спецприз', 'приз']),
#               Sense(keyword='медаль', cluster=['грамоту', 'медаль']),
#               Sense(keyword='ВУЗ', cluster=['ВУЗ'])],
#              'директор': [Sense(keyword='директора', cluster=['ген.директор', 'финдиректор', 'Зам.директора', 'замдиректора', 'и.о.директора', 'зам.директора', 'деректор', 'директора', '-руководитель', 'гендиректор', 'диреκтοр', 'Замдиректора', 'экс-директор', '-директор', 'Ген.директор', '.Директор', 'вице-директор']),
#               Sense(keyword='основатель', cluster=['топ-менеджер', 'инженер', 'сооснователь', 'совладелец', 'генеральный', 'секретарь', 'основатель', 'продюсер', 'менеджер', 'куратор', 'координатор', 'председатель'])],
#              'диск': [Sense(keyword='компакт-диск', cluster=['СD-диск', 'компакт-диск', 'мастер-диск', 'мини-диск']),
#               Sense(keyword='диска', cluster=['диски', 'диска', 'диск.', 'диска.']),
#               Sense(keyword='терабайтный', cluster=['перезаписываемый', 'терабайтный']),
#               Sense(keyword='диск2', cluster=['диск2']),
#               Sense(keyword='диск3', cluster=['диск3'])],
#              'дискант': [Sense(keyword='хорист', cluster=['саксофон', 'бас', 'баритональный', 'Фальцет', 'тенор', 'певчий', 'виброфон', 'баритон', 'кларнет', 'бас-баритон', 'контратенор', 'хорист', 'контрабас']),
#               Sense(keyword='хриплый', cluster=['обертон', 'визгливый', 'звучный', 'сиплый', 'хрипловатый', 'безголосый', 'глуховатый', 'хриплый', 'рокочущий', 'писклявый', 'полнозвучный']),
#               Sense(keyword='солирующий', cluster=['оркестровый', 'басовый', 'солирующий', 'аккордовый']),
#               Sense(keyword='форшлаг', cluster=['флажолет', 'органум', 'форшлаг']),
#               Sense(keyword='дисканты', cluster=['дискантом', 'дисканты'])],
#              'дистанция': [Sense(keyword='марафонская', cluster=['Спринтерская', 'гонка', 'эстафета', 'марафонская', 'стометровка', 'лыжня', 'спринтерская', '10-километровая']),
#               Sense(keyword='длинна', cluster=['длинна', 'длина', 'глубина']),
#               Sense(keyword='возрастная', cluster=['возрастная']),
#               Sense(keyword='дистанцией', cluster=['дистанцией']),
#               Sense(keyword='расстояние', cluster=['расстояние']),
#               Sense(keyword='малокалиберная', cluster=['малокалиберная']),
#               Sense(keyword='расстояния', cluster=['расстояния']),
#               Sense(keyword='Дальность', cluster=['Дальность']),
#               Sense(keyword='дальность', cluster=['дальность'])],
#              'дитя': [Sense(keyword='умирающее', cluster=['рожденное', 'умирающее', 'родившееся']),
#               Sense(keyword='дитём', cluster=['дитём', 'детя', 'дитятю']),
#               Sense(keyword='дитяти', cluster=['младенца', 'дитяти']),
#               Sense(keyword='чудовище', cluster=['сокровище', 'чудовище']),
#               Sense(keyword='капризное', cluster=['избалованное', 'капризное']),
#               Sense(keyword='материнское', cluster=['материнское'])],
#              'дичь': [Sense(keyword='рыбу', cluster=['козлятину', 'живность', 'рыбу']),
#               Sense(keyword='косулю', cluster=['косулю', 'глухаря']),
#               Sense(keyword='утка', cluster=['утка', 'птица']),
#               Sense(keyword='охотничья', cluster=['охотничья', 'охота'])],
#              'длина': [Sense(keyword='ширина2', cluster=['ширина2', 'см.длина', 'массаДлина', '18Длина', '2Длина', 'ммдлина', '-высота', '-длина', 'кг.Длина', '5Длина', '25Длина', '4Длина', 'м2Длина', '8Длина', 'мм.Длина', '7Длина', 'м.Длина', '58Длина', '19Длина']),
#               Sense(keyword='длинна', cluster=['Высота', 'размер', 'высота', 'ширина', 'Ширина', 'длинна', 'протяженность', 'протяжённость', 'длиная', 'длиной'])],
#              'дневник': [Sense(keyword='ежедневник', cluster=['дневник.', 'фотодневник', 'блокнотик', 'Дневнике', 'блог', 'тетрадка', 'ежедневник', 'видео-дневник', 'видеодневник', 'планнер', 'фотоальбом', 'видеоблог', 'днев', 'тетрадь', 'онлайн-дневник', 'журнал', 'дневничок', 'Дневничок', 'тетрадку', 'интернет-дневник', 'блокнот', 'дневником', 'листок', 'бортжурнал']),
#               Sense(keyword='дневники', cluster=['дневников', 'самонаблюдений', 'дневниках', 'дневниковая', 'дневники', 'записки', 'дневниковые', 'Дневники']),
#               Sense(keyword='черновик', cluster=['отчет', 'рассказ', 'мемуар', 'черновик'])],
#              'днище': [Sense(keyword='подкапотное', cluster=['воздухозаборное', 'подкапотное', 'броневое']),
#               Sense(keyword='капоте', cluster=['глушаке', 'брызговике', 'капоте']),
#               Sense(keyword='дно', cluster=['дно', 'корыто']),
#               Sense(keyword='дне', cluster=['дне']),
#               Sense(keyword='крышке', cluster=['крышке']),
#               Sense(keyword='кузов', cluster=['кузов'])],
# ...
#               Sense(keyword='стрела-змея', cluster=['олигодон', 'стрела-змея', 'ужак']),
#               Sense(keyword='полоза', cluster=['полоза']),
#               Sense(keyword='узорчатый', cluster=['узорчатый']),
#               Sense(keyword='полозы', cluster=['полозы'])],
#              'пост': [Sense(keyword='поста', cluster=['фактум', 'постов', 'посты', 'постом', 'Посты', 'вакантен', 'должность', 'поста', 'заступивший']),
#               Sense(keyword='коммент', cluster=['Комент', 'коммент', 'комент', 'комменарий']),
#               Sense(keyword='постик', cluster=['постик', 'топик', 'рассказик', 'фотопост']),
#               Sense(keyword='пοст', cluster=['пοст', 'постВ', 'саум']),
#               Sense(keyword='твитт', cluster=['постинг', 'перепост', 'твитт']),
#               Sense(keyword='постный', cluster=['постный', 'постПост']),
#               Sense(keyword='поститься', cluster=['постится', 'поститься']),
#               Sense(keyword='премьерский', cluster=['премьерский']),
#               Sense(keyword='блоге', cluster=['блоге'])],
#              'поток': [Sense(keyword='наплыв', cluster=['вихрь', 'хлынувший', 'прилив', 'отток', 'изливающийся', 'всплеск', 'приток', 'нахлынувший', 'наплыв', 'шквал', 'Приток']),
#               Sense(keyword='потока', cluster=['потоке', 'потоков', 'потока', 'потоках', 'потокам', 'Потоком', 'потоком', 'Потоки', 'потоками']),
#               Sense(keyword='нескончаемый', cluster=['бесконечный', 'неиссякающий', 'нескончаемый', 'круговорот']),
#               Sense(keyword='ручеёк', cluster=['ручеек', 'ручеёк']),
#               Sense(keyword='поток.', cluster=['поток.']),
#               Sense(keyword='циркулирующий', cluster=['циркулирующий']),
#               Sense(keyword='луч', cluster=['луч']),
#               Sense(keyword='канал', cluster=['канал']),
#               Sense(keyword='объем', cluster=['объем'])],
#              'почерк': [Sense(keyword='почерку', cluster=['графолога', 'почерках', 'почерком', 'почерка', 'Графология', 'почерке', 'почерку', 'почерки', 'почерков', 'скоропись']),
#               Sense(keyword='угловатый', cluster=['витиеватый', 'замысел', 'замысловатый', 'угловатый', 'размашистый', 'неразборчивый', 'корявый', 'росчерк', 'вычурный']),
#               Sense(keyword='фотопортрет', cluster=['силуэт', 'портрет', 'рисунок', 'портретик', 'фотопортрет']),
#               Sense(keyword='характер', cluster=['талант', 'темперамент', 'характер', 'стиль']),
#               Sense(keyword='шрифт', cluster=['шрифт', 'текст-то', 'текст']),
#               Sense(keyword='подчерк', cluster=['отточенный', 'узнаваемый', 'подчерк']),
#               Sense(keyword='рукописный', cluster=['каллиграфический', 'рукописный'])],
#              'пробка': [Sense(keyword='гильза', cluster=['гильза']),
#               Sense(keyword='затор', cluster=['затор']),
#               Sense(keyword='пробковая', cluster=['пробковая']),
#               Sense(keyword='ручка', cluster=['ручка'])],
#              'проказа': [Sense(keyword='малярия', cluster=['лепра', 'малярия']),
#               Sense(keyword='проказою', cluster=['проказою']),
#               Sense(keyword='нечистота', cluster=['нечистота']),
#               Sense(keyword='невзгода', cluster=['невзгода']),
#               Sense(keyword='прокаженного', cluster=['прокаженного'])],
#              'пропасть': [Sense(keyword='бездну', cluster=['неизведанность', 'бездна', 'бездонность', 'бесконечность', 'неизвестность', 'бездну', 'пропастей', 'зияющая']),
#               Sense(keyword='перескочить', cluster=['перепрыгнуть', 'перескочить']),
#               Sense(keyword='упасть', cluster=['упасть', 'рухнуть']),
#               Sense(keyword='пасть', cluster=['пасть'])],
#              'проспект': [Sense(keyword='пр-кт', cluster=['проспект.', 'проспекте', 'Автозаводцев', 'пр-кт.', 'просп', 'пр-кт', 'Краснозвездный', 'пр-т', 'проспект1', 'просп.Ленина', 'Пр-кт']),
#               Sense(keyword='проспекты', cluster=['проспекта', 'проспектом', 'проспекту', 'проспе', 'переулок', 'проспекты', 'бульвар', 'проспектов']),
#               Sense(keyword='квартирапроспект', cluster=['Ленинапроспект', 'Космонавтовпроспект', 'Дзержинскогопроспект', 'квартирапроспект', 'Победыпроспект', 'Мирапроспект'])],
#              'пытка': [Sense(keyword='тюрьма', cluster=['казнь', 'тюрьма', 'насильственная', 'каторга', 'смертная', 'пыточная', 'расправа']),
#               Sense(keyword='попытка', cluster=['провокация', 'изощренная', 'забава', 'манипуляция', 'уловка', 'попытка']),
#               Sense(keyword='щекотка', cluster=['сатисфакция', 'порка', 'трепка', 'щекотка', 'мастурбация']),
#               Sense(keyword='нестерпимая', cluster=['адская', 'Мучительная', 'изнуряющая', 'нестерпимая']),
#               Sense(keyword='пыткой', cluster=['пыткой', 'пытками', 'пыток']),
#               Sense(keyword='разлука', cluster=['мучительна', 'разлука']),
#               Sense(keyword='Попытка', cluster=['Попытка']),
#               Sense(keyword='мучение', cluster=['мучение']),
#               Sense(keyword='агония', cluster=['агония']),
#               Sense(keyword='мучительница', cluster=['мучительница']),
#               Sense(keyword='голодовка', cluster=['голодовка'])],
#              'рак': [Sense(keyword='фиброматоз', cluster=['псориаз', 'лимфогранулематоз', 'фиброматоз', 'саркоидоз', 'аденоматоз', 'туберкулез', 'аденоз', 'лейкоз', 'папилломатоз', 'аденома']),
#               Sense(keyword='раковый', cluster=['мелкоклеточный', 'злокачественный', 'плоскоклеточный', 'раковый', 'Плоскоклеточный']),
#               Sense(keyword='инфаркт', cluster=['инфаркт', 'диабет', 'цирроз', 'инсульт']),
#               Sense(keyword='рака', cluster=['рака']),
#               Sense(keyword='раке', cluster=['раке']),
#               Sense(keyword='рак.', cluster=['рак.']),
#               Sense(keyword='болезнь', cluster=['болезнь'])],
#              'рок': [Sense(keyword='джаз', cluster=['джаз']),
#               Sense(keyword='рок-', cluster=['рок-']),
#               Sense(keyword='рэп', cluster=['рэп'])],
#              'рысь': [Sense(keyword='косулю', cluster=['косулю', 'росомаху', 'пантеру', 'кошку', 'куницу', 'лисицу']),
#               Sense(keyword='косуля', cluster=['длиннохвостая', 'косуля', 'гаичка']),
#               Sense(keyword='ящерица', cluster=['ящерица', 'пума', 'кошка']),
#               Sense(keyword='Пума', cluster=['Пума'])],
#              'свет': [Sense(keyword='свет.В', cluster=['озаряющий', 'свет-то', 'невечерний', 'мерцающий', 'излучаемый', 'отблеск', 'негасимый', 'солнечный', 'гаснущий', 'рассеивающийся', 'тусклый', 'Неяркий', 'светоносный', 'свет.', 'испущенный', 'ослепительный', 'Слепящий', 'ослепляющий', 'луч', 'лучик', 'свет.Я', 'свет.В', 'неяркий', 'пробивающийся', 'божий', 'Невечерний', 'Cвет']),
#               Sense(keyword='света', cluster=['света']),
#               Sense(keyword='ксеноновый', cluster=['ксеноновый']),
#               Sense(keyword='звук', cluster=['звук']),
#               Sense(keyword='проливающее', cluster=['проливающее'])],
#              'секрет': [Sense(keyword='секретом', cluster=['секрета', 'секретами', 'секреты', 'секретом', 'тайны', 'Полишинеля', 'секрете', 'секретов', '.Секрет', 'секретах', 'Секретом', 'Секреты']),
#               Sense(keyword='парадокс', cluster=['факт', 'нюанс', 'феномен', 'парадокс', 'общеизвестный', 'принцип', 'аспект', 'рецепт', 'смысл', 'цимус']),
#               Sense(keyword='причина', cluster=['заключается', 'кроется', 'загадка', 'причина', 'разгадка', 'таится', 'подвох']),
#               Sense(keyword='секрет-', cluster=['Раскрою', 'секрет-', 'Открою', 'открою']),
#               Sense(keyword='удивительный', cluster=['сокровенный', 'удивительный', 'секретный', 'тайный']),
#               Sense(keyword='53Ни', cluster=['53Ни']),
#               Sense(keyword='почему', cluster=['почему']),
#               Sense(keyword='притягательности', cluster=['притягательности']),
#               Sense(keyword='Раскрыт', cluster=['Раскрыт']),
#               Sense(keyword='секрет.', cluster=['секрет.'])],
#              'скат': [Sense(keyword='щелкун', cluster=['слепыш', 'зубатый', 'гремучник', 'бычек', 'пилорыл', 'змеевидный', 'двухвостый', 'полоз', 'вертун', 'плавун', 'щелкун', 'камышовый', 'рогач', 'бурун']),
#               Sense(keyword='утес', cluster=['гребень', 'риф', 'песчаный', 'склон', 'утес', 'скалистый', 'отвесный', 'волнорез']),
#               Sense(keyword='скатом', cluster=['манта', 'скаты', 'скате', 'скатные', 'скатом', 'скатов', 'ската']),
#               Sense(keyword='водосточный', cluster=['водоскат', 'водосточный']),
#               Sense(keyword='торос', cluster=['перемет', 'торос']),
#               Sense(keyword='полуметровый', cluster=['полуметровый']),
#               Sense(keyword='донный', cluster=['донный']),
#               Sense(keyword='горбыль', cluster=['горбыль']),
#               Sense(keyword='краб', cluster=['краб']),
#               Sense(keyword='выгнутый', cluster=['выгнутый'])],
#              'слог': [Sense(keyword='ямб', cluster=['интонационный', 'возвышенный', 'певуч', 'патетический', 'поэтический', 'напевный', 'поэтичный', 'просторечный', 'цветистый', 'лапидарный', 'стиш', 'высокопарный', 'метафоричный', 'афористичный', 'певучий', 'отрывистый', 'стихотворный', 'стих', 'ямб']),
#               Sense(keyword='слога', cluster=['ударением', 'ударения', 'слогу', 'ударение', 'слогом', 'слоге', 'слоги', 'слога'])],
#              'среда': [Sense(keyword='окружающая', cluster=['Бизнес-среда', 'микросреда', 'окружающая', 'бизнес-среда', 'Микросреда', 'биосистема', 'техносфера', 'макросреда', 'Макросреда']),
#               Sense(keyword='пятница', cluster=['пятница', 'середа', 'среда-четверг', 'предметно-пространственная', 'суббота', 'среда-', 'среда8']),
#               Sense(keyword='обитания', cluster=['обитания']),
#               Sense(keyword='средой', cluster=['средой']),
#               Sense(keyword='Окружающая', cluster=['Окружающая'])],
#              'стан': [Sense(keyword='дартам', cluster=['дарты', 'дартов', 'дартные', 'стан-', 'дартных', 'электростан', 'дарт', 'нестан', 'дартам']),
#               Sense(keyword='трубопрокатный', cluster=['волочильный', 'ткацкий', 'кузнечный', 'ковочный', 'трубопрокатный', 'листопрокатный']),
#               Sense(keyword='неприятельский', cluster=['вражий', 'вражеский', 'неприятельский']),
#               Sense(keyword='стана', cluster=['станами', 'стана', 'Казах']),
#               Sense(keyword='тан', cluster=['тан', 'валь']),
#               Sense(keyword='ковый', cluster=['ковый', 'вальный']),
#               Sense(keyword='сион', cluster=['сион']),
#               Sense(keyword='стан.', cluster=['стан.']),
#               Sense(keyword='стане', cluster=['стане']),
#               Sense(keyword='соболий', cluster=['соболий']),
#               Sense(keyword='Сетуньский', cluster=['Сетуньский']),
#               Sense(keyword='стани', cluster=['стани']),
#               Sense(keyword='раскат', cluster=['раскат']),
#               Sense(keyword='половецкий', cluster=['половецкий']),
#               Sense(keyword='стри', cluster=['стри']),
#               Sense(keyword='нотный', cluster=['нотный']),
#               Sense(keyword='Даге', cluster=['Даге']),
#               Sense(keyword='м.Теплый', cluster=['м.Теплый']),
#               Sense(keyword='дуна', cluster=['дуна'])],
#              'стопка': [Sense(keyword='стопок', cluster=['стопках', 'стопок', 'стопкой', 'стопкам', 'стопками']),
#               Sense(keyword='четвертушка', cluster=['четвертушка', 'рюмочка', 'бутылка', 'фляга', 'фляжка']),
#               Sense(keyword='стопочка', cluster=['кипа', 'Пачка', 'стопочка', 'пачка']),
#               Sense(keyword='тетрадка', cluster=['тетрадка'])],
#              'суда': [Sense(keyword='судов', cluster=['прокурора', 'судов', 'спецсуда', 'прокуратуры', 'инстанции', 'райсудов', 'Мосгорсуда', 'экс-судьи', 'судьи']),
#               Sense(keyword='суда.', cluster=['суда.', 'суда.Как', 'суда.В', 'суда.Постановление', 'суда-', 'суда.По']),
#               Sense(keyword='апелляционного', cluster=['апелляционного', 'Конституционного', 'Верховного', 'Кассационного']),
#               Sense(keyword='судилища', cluster=['судилища']),
#               Sense(keyword='правосудия', cluster=['правосудия']),
#               Sense(keyword='ревтрибунала', cluster=['ревтрибунала'])],
#              'таз': [Sense(keyword='тазик', cluster=['бочонок', 'мешок', 'тазик', 'корыто', 'поддон', 'кипяток', 'бидон', 'бачок', 'кувшин', 'лохань', 'тазика', 'поднос', 'чугунок', 'сосуд', 'подойник', 'ящик', 'горшок', 'ковшик', 'горшочек', 'кадушку', 'кувшинчик', 'бочок', 'бидончик', 'кастрюлю']),
#               Sense(keyword='тазе', cluster=['тазике', 'тазиком', 'тазу', 'тазе', 'таза', 'тазом']),
#               Sense(keyword='живот', cluster=['живот', 'пупок', 'торс', 'животик', 'лобок']),
#               Sense(keyword='тазовый', cluster=['тазовый', 'копчик', 'крестец']),
#               Sense(keyword='тазы', cluster=['тазов', 'тазики', 'тазы']),
#               Sense(keyword='валик', cluster=['валик']),
#               Sense(keyword='наклони', cluster=['наклони']),
#               Sense(keyword='тазовые', cluster=['тазовые'])],
#              'такса': [Sense(keyword='собачка', cluster=['собачка', 'обезьянка']),
#               Sense(keyword='таксах', cluster=['таксах', 'такс'])],
#              'тюрьма': [Sense(keyword='психушка', cluster=['колония', 'лагерная', 'темница', 'психушка', 'исправительная', 'Исправительная', 'каторжная', 'тюремная', 'Гауптвахта', 'неволя', 'тюрма', 'виселица', 'больница']),
#               Sense(keyword='тюрьмой', cluster=['тюрьмой']),
#               Sense(keyword='депортация', cluster=['депортация']),
#               Sense(keyword='тюремное', cluster=['тюремное'])],
#              'хвост': [Sense(keyword='хвостик', cluster=['хвостик', 'обрубленный', 'саблевидный', 'хобот', 'клюв', 'хвосты', 'отрос', 'гребень', 'крючковатый', 'распушенный', 'коготь', 'хвост.', 'Плавник', 'плавничок', 'плавник', 'гребешок', 'крылья', 'парик', 'хвостики', 'шиньон', 'кончик', 'плавники', 'чубчик']),
#               Sense(keyword='гриву', cluster=['хвостом', 'хвосту', 'хвосте', 'хвостовой', 'павлина', 'хвостами', 'гриву', 'хвоста']),
#               Sense(keyword='лапы', cluster=['загривок', 'копчик', 'лапы', 'шлея', 'вожжа']),
#               Sense(keyword='русалочий', cluster=['павлиний', 'лисий', 'русалочий', 'ласточкин'])],
#              'шах': [Sense(keyword='калиф', cluster=['калиф']),
#               Sense(keyword='шахом', cluster=['шахом']),
#               Sense(keyword='персидский', cluster=['персидский']),
#               Sense(keyword='ферзю', cluster=['ферзю']),
#               Sense(keyword='ферзь', cluster=['ферзь']),
#               Sense(keyword='шаханшах', cluster=['шаханшах']),
#               Sense(keyword='Вологез', cluster=['Вологез']),
#               Sense(keyword='шахов', cluster=['шахов'])],
#              'шашка': [Sense(keyword='черкеска', cluster=['казачья', 'нагайка', 'тачанка', 'бурка', 'папаха', 'черкеска', 'буденовка', 'будёновка', 'гимнастёрка']),
#               Sense(keyword='шпага', cluster=['дубинка', 'полусабля', 'сабли', 'гренада', 'шпага', 'сабля', 'булава', 'Нагайка']),
#               Sense(keyword='пушка', cluster=['пуля', 'пушка', 'гильза', 'картечь', 'винтовка']),
#               Sense(keyword='шашках', cluster=['шашками', 'шашек', 'шашках']),
#               Sense(keyword='зажигалка', cluster=['зажигалка']),
#               Sense(keyword='дымовая', cluster=['дымовая'])],
#              'штамп': [Sense(keyword='знак-', cluster=['датер', 'самонаборный', 'трафаретный', 'маркировочный', 'Оттиск', 'бумажный', 'наклеенный', 'штемпель', 'клеймо', 'стикер', 'флажок', 'оттиск', 'маркер', 'дубликат', 'знак-', 'штемпельный']),
#               Sense(keyword='штампик', cluster=['эмбосинг', 'штампинг', 'чипик', 'дырокольный', 'чипборд', 'трафарет', 'штампик', 'Штампик', 'полужемчуг', 'дырокол', 'примовский']),
#               Sense(keyword='штампе', cluster=['штампе', 'штампа', 'паспорте', 'штампиком', 'штампы', 'штампом', 'штампами', 'штампах', 'штампов']),
#               Sense(keyword='расхожий', cluster=['расхожий'])]})

# %%
# implement the wsi by looking at the inventory file 

# for methon in keyword or mean

for nns in [50, 100, 200]:
    inventory_fpath = "/home/panchenko/sensegram/model/cc.ru.300.vec.gz.top{}.inventory.tsv".format(nns)
    print(inventory_fpath)
    
    # load the inventory
    
    # load the evaluation dataset
    
    # for each context in the evaluation dataset
        # find the most suitale context
