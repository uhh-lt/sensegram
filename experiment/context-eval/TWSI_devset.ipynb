# %% [markdown]
# # Split TWSI dataset into development and test sets.

# %%
import pandas
reader = pandas.read_csv('context-eval/data/Dataset-TWSI-2.csv', encoding="utf-8", delimiter="\t", dtype={'predict_related': object, 'gold_sense_ids':object, 'predict_sense_ids':object})
instances = reader

# %% [markdown]
# ## Initial statistics

# %%
print "Instaces: ", len(instances)
print "Senses: ", len(instances.groupby(['target', 'gold_sense_ids']))
print "Words: ", len(instances.target.unique())
# Out:
# Instaces:  145140
# Senses:  2403
# Words:  1012

# %% [markdown]
# ## Delete instances with undefined senses (no substitutions provided)

# %%
undef = instances[instances.golden_related.isnull()]
print "Undef instaces: ", len(undef)
print "in ", len(undef.target.unique()), " words: ", undef.target.unique()[:10], "..."
print "Examples: "
undef[undef.target == 'block'].tail()
# Out:
# Undef instaces:  2477
# in  88  words:  [u'application' u'baby' u'basis' u'bit' u'block' u'bronze' u'CD'
#  u'challenge' u'circle' u'club'] ...
# Examples:
#        context_id target target_pos target_position gold_sense_ids  \
# 11799     1572268  block          n           68,74             11
# 11800    29219101  block          n         194,199             11
# 11801    57130314  block          n            6,12             11
# 11955     3540731  block          n         105,111              8
# 11956    33626434  block          n         104,110              8
#
#       predict_sense_ids golden_related predict_related  \
# 11799               NaN            NaN             NaN
# 11800               NaN            NaN             NaN
# 11801               NaN            NaN             NaN
# 11955               NaN            NaN             NaN
# 11956               NaN            NaN             NaN
#
#                                                  context
# 11799  Polymer scientists use thermodynamics to descr...
# 11800  TPF will allow certain types of function trace...
# 11801  These blocks are mot commonly referred to as m...
# 11955  Played in each of the final four matches ( eig...
# 11956  Paris is the only player in NCAA history , mal...

# %%
instances = instances[~instances.golden_related.isnull()]
print "Instaces: ", len(instances)
print "Senses: ", len(instances.groupby(['target', 'gold_sense_ids']))
print "Words: ", len(instances.target.unique())
# Out:
# Instaces:  142663
# Senses:  2288
# Words:  1012

# %% [markdown]
# ## Count instances for every word sense

# %%
wordsenses = instances.groupby(['target', 'gold_sense_ids'], sort = False)['context_id'].apply(lambda x: len(x.unique()))
wordsenses = wordsenses.reset_index().rename(columns = {'context_id':'inst_count'})
wordsenses.head(n=20)
# Out:
#       target gold_sense_ids  inst_count
# 0    ability              1          98
# 1   academic              1         114
# 2   academic              2          56
# 3   academic              3          10
# 4     access              1          95
# 5   accident              1         184
# 6   accident              2           9
# 7    account              1          69
# 8    account              2          29
# 9       acid              1         188
# 10      acid              2           2
# 11       act              1          84
# 12       act              2          28
# 13       act              3          34
# 14       act              4           4
# 15    action              1          79
# 16    action              2          12
# 17  activity              1          97
# 18     actor              1          91
# 19   actress              1          99

# %% [markdown]
# ## Find words with unfrequents senses (less than 5 instances)

# %%
unfreq_senses = wordsenses[wordsenses.inst_count < 5]
print "Senses with less than 5 instances: ", len(unfreq_senses)
words_unfreq_senses = unfreq_senses.target.unique()
print "Number of words with unfrequent senses: ", len(words_unfreq_senses)
print "Examples of such words: ", words_unfreq_senses[:15]
# Out:
# Senses with less than 5 instances:  218
# Number of words with unfrequent senses:  165
# Examples of such words:  [u'acid' u'act' u'advance' u'agent' u'amount' u'article' u'baby' u'bar'
#  u'basis' u'bill' u'bit' u'block' u'board' u'bottom' u'boundary']

# %% [markdown]
# ## Remove words with unfrequent senses (completely)

# %%
wordsenses = wordsenses[~wordsenses.target.isin(words_unfreq_senses)]
print "Number of senses after removal: ", len(wordsenses)
print "Number of words after removal: ", len(wordsenses.target.unique())
wordsenses.head(n=20)
# Out:
# Number of senses after removal:  1617
# Number of words after removal:  847
#             target gold_sense_ids  inst_count
# 0          ability              1          98
# 1         academic              1         114
# 2         academic              2          56
# 3         academic              3          10
# 4           access              1          95
# 5         accident              1         184
# 6         accident              2           9
# 7          account              1          69
# 8          account              2          29
# 15          action              1          79
# 16          action              2          12
# 17        activity              1          97
# 18           actor              1          91
# 19         actress              1          99
# 20        addition              1          65
# 21        addition              2           9
# 22  administration              1          59
# 23  administration              2          36
# 24           adult              1         161
# 25           adult              2           7

# %% [markdown]
# ## Count senses for every word

# %%
words = wordsenses.groupby('target', sort=False)['gold_sense_ids'].apply(lambda x: len(x.unique()))
words = words.reset_index().rename(columns = {'gold_sense_ids':'sense_count'})
words.head(n=20)
# Out:
#             target  sense_count
# 0          ability            1
# 1         academic            3
# 2           access            1
# 3         accident            2
# 4          account            2
# 5           action            2
# 6         activity            1
# 7            actor            1
# 8          actress            1
# 9         addition            2
# 10  administration            2
# 11           adult            2
# 12       advantage            2
# 13     advertising            2
# 14             age            2
# 15          agency            2
# 16       agreement            2
# 17             aid            3
# 18             air            4
# 19        aircraft            1

# %% [markdown]
# ## Remove words that have only one sense

# %%
multisemous_words = words[words.sense_count > 1]
print "Multisemous words: ", len(multisemous_words)
print "Senses in multisemous words: ", sum(multisemous_words.sense_count)
multisemous_words
# Out:
# Number of multisemous words:  463
# Number of senses of multisemous words:  1233
#              target  sense_count
# 1          academic            3
# 3          accident            2
# 4           account            2
# 5            action            2
# 9          addition            2
# 10   administration            2
# 11            adult            2
# 12        advantage            2
# 13      advertising            2
# 14              age            2
# 15           agency            2
# 16        agreement            2
# 17              aid            3
# 18              air            4
# 22      alternative            3
# 26           answer            2
# 27       appearance            2
# 28      application            2
# 29         approach            2
# 31     architecture            2
# 33         argument            2
# 34              arm            4
# 36          arrival            3
# 37              art            2
# 39          assault            2
# 42      association            4
# 49        authority            3
# 51             back            4
# 52       background            3
# 53             ball            2
# ..              ...          ...
# 794            tree            2
# 795           trial            3
# 797              TV            2
# 799     underground            3
# 800           union            4
# 801            unit            4
# 803           usage            2
# 804             use            2
# 807           value            2
# 810            vice            3
# 813            view            2
# 816          vision            4
# 817           visit            2
# 818          visual            2
# 819           vocal            2
# 820           voice            3
# 821          volume            2
# 822            vote            2
# 823            wall            3
# 825           water            2
# 826             way            2
# 828            wear            2
# 831            week            2
# 832          weight            3
# 834           wheel            2
# 836          window            3
# 841            wood            2
# 842            work            2
# 843           world            3
# 845           youth            2
#
# [463 rows x 2 columns]

# %% [markdown]
# ## Create and save devsets
# * **devset** -- 5 instances for each sense of multisemous words
# * **devset_with_mono** -- 5 instanses for each sense of multisemous and monosemous words

# %%
devset = instances[instances.target.isin(multisemous_words.target)].groupby(['target', 'gold_sense_ids']).head(5)

print "Instances in development set (multisense only): ", len(devset)
print "Senses: ", len(devset.groupby(['target', 'gold_sense_ids']))
print "Words: ", len(devset.target.unique())
print ("Precentage of original dataset: %.2f%%" % (100*float(len(devset))/145140))
print "Examlpe: "
devset.head(10)
# Out:
# Instances in development set (multisense only):  6165
# Senses:  1233
# Words:  463
# Precentage of original dataset: 4.25%
# Examlpe:
#      context_id    target target_pos target_position gold_sense_ids  \
# 98       572658  academic          n            4,12              1
# 99      8598564  academic          n           55,63              1
# 100    10376001  academic          n           20,28              1
# 101    10654142  academic          n         110,118              1
# 102    11874260  academic          n          99,107              1
# 212     1405871  academic          n          93,101              2
# 213     2502562  academic          n           24,32              2
# 214     5169432  academic          n         255,263              2
# 215     5529473  academic          n           67,75              2
# 216    13444483  academic          n           19,27              2
#
#     predict_sense_ids                                     golden_related  \
# 98                NaN  scholastic:21, educational:13, scholarly:9, un...
# 99                NaN  scholastic:21, educational:13, scholarly:9, un...
# 100               NaN  scholastic:21, educational:13, scholarly:9, un...
# 101               NaN  scholastic:21, educational:13, scholarly:9, un...
# 102               NaN  scholastic:21, educational:13, scholarly:9, un...
# 212               NaN  school:3, educational:2, scholastic:2, school ...
# 213               NaN  school:3, educational:2, scholastic:2, school ...
# 214               NaN  school:3, educational:2, scholastic:2, school ...
# 215               NaN  school:3, educational:2, scholastic:2, school ...
# 216               NaN  school:3, educational:2, scholastic:2, school ...
#
#     predict_related                                            context
# 98              NaN  The academic rigour of our business programs i...
# 99              NaN  Torch Trinity is an inter - denominational the...
# 100             NaN  Having finished the academic part the now Leut...
# 101             NaN  IQ and the Wealth of Nations ' was not peer - ...
# 102             NaN  \" The Dukes of Hazzard , Television ' s Simpl...
# 212             NaN  The KHSAA rule is that students must be under ...
# 213             NaN  During the 1985 to 1986 academic year , he lec...
# 214             NaN  A detailed announcement describing the selecti...
# 215             NaN  When these new programs elevate to varsity sta...
# 216             NaN  Today more than 60 academic staff work at SSEE...

# %%
devset_with_mono = instances[instances.target.isin(words.target)].groupby(['target', 'gold_sense_ids']).head(5)

print "Instances in development set (multisense and monosense): ", len(devset_with_mono)
print "Senses: ", len(devset_with_mono.groupby(['target', 'gold_sense_ids']))
print "Words: ", len(devset_with_mono.target.unique())
print ("Precentage of original dataset: %.2f%%" % (100*float(len(devset_with_mono))/145140))
print "Examlpe: "
devset_with_mono.head(15)
# Out:
# Instances in development set (multisense and monosense):  8085
# Senses:  1617
# Words:  847
# Precentage of original dataset: 5.57%
# Examlpe:
#      context_id    target target_pos target_position gold_sense_ids  \
# 0      10038908   ability          n         160,169              1
# 1       1418247   ability          n           45,54              1
# 2      23647997   ability          n           90,99              1
# 3      30973207   ability          n         110,119              1
# 4       3369783   ability          n           30,39              1
# 98       572658  academic          n            4,12              1
# 99      8598564  academic          n           55,63              1
# 100    10376001  academic          n           20,28              1
# 101    10654142  academic          n         110,118              1
# 102    11874260  academic          n          99,107              1
# 212     1405871  academic          n          93,101              2
# 213     2502562  academic          n           24,32              2
# 214     5169432  academic          n         255,263              2
# 215     5529473  academic          n           67,75              2
# 216    13444483  academic          n           19,27              2
#
#     predict_sense_ids                                     golden_related  \
# 0                 NaN  capability:33, capacity:29, skill:19, power:15...
# 1                 NaN  capability:33, capacity:29, skill:19, power:15...
# 2                 NaN  capability:33, capacity:29, skill:19, power:15...
# 3                 NaN  capability:33, capacity:29, skill:19, power:15...
# 4                 NaN  capability:33, capacity:29, skill:19, power:15...
# 98                NaN  scholastic:21, educational:13, scholarly:9, un...
# 99                NaN  scholastic:21, educational:13, scholarly:9, un...
# 100               NaN  scholastic:21, educational:13, scholarly:9, un...
# 101               NaN  scholastic:21, educational:13, scholarly:9, un...
# 102               NaN  scholastic:21, educational:13, scholarly:9, un...
# 212               NaN  school:3, educational:2, scholastic:2, school ...
# 213               NaN  school:3, educational:2, scholastic:2, school ...
# 214               NaN  school:3, educational:2, scholastic:2, school ...
# 215               NaN  school:3, educational:2, scholastic:2, school ...
# 216               NaN  school:3, educational:2, scholastic:2, school ...
#
#     predict_related                                            context
# 0               NaN  The following year , Harchester United reached...
# 1               NaN  He has also more than once overestimated his a...
# 2               NaN  According to this theory , if Dio existed at t...
# 3               NaN  Their main goal was to produce an extremely st...
# 4               NaN  Known for his astute tactical abilities , he i...
# 98              NaN  The academic rigour of our business programs i...
# 99              NaN  Torch Trinity is an inter - denominational the...
# 100             NaN  Having finished the academic part the now Leut...
# 101             NaN  IQ and the Wealth of Nations ' was not peer - ...
# 102             NaN  \" The Dukes of Hazzard , Television ' s Simpl...
# 212             NaN  The KHSAA rule is that students must be under ...
# 213             NaN  During the 1985 to 1986 academic year , he lec...
# 214             NaN  A detailed announcement describing the selecti...
# 215             NaN  When these new programs elevate to varsity sta...
# 216             NaN  Today more than 60 academic staff work at SSEE...

# %%
devset.to_csv("dev_TWSI.csv", sep='\t', na_rep='', index=False, encoding="utf-8")
devset_with_mono.to_csv("dev_TWSI_with_mono.csv", sep='\t', na_rep='', index=False, encoding="utf-8")

# %%
[(devset.target == "club") & (devset.gold_sense_ids == '3')].context
# Out:
# 23012    The white rappers awaken and are soon met by M...
# 23013    In 1984 , while recording Nina Hagen In Ekstas...
# 23014    The 1970 fire that destroyed four of the club ...
# 23015    Atlantic Palace night club &amp; casino , tax ...
# 23016    Some Dirty Knobs material has been recorded an...
# Name: context, dtype: object
